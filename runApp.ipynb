# %%
# %run utils/training_pipeline.py
# Out:
# Training: Logistic Regression
#
# Training: Decision Tree
#
# Training: KNN
#
# Training: Naive Bayes
#
# Training: Random Forest
#
# Training: XGBoost
#
# ✅ Model comparison saved: artifacts/model_comparison.csv
#                  Model  Accuracy       AUC  Precision    Recall        F1  \
# 0  Logistic Regression  0.738112  0.841298   0.504303  0.783422  0.613613
# 1        Decision Tree  0.728176  0.649570   0.487805  0.481283  0.484522
# 2                  KNN  0.765082  0.804941   0.555556  0.574866  0.565046
# 3          Naive Bayes  0.694819  0.807419   0.458944  0.836898  0.592803
# 4        Random Forest  0.781405  0.821673   0.617021  0.465241  0.530488
# 5              XGBoost  0.791341  0.832712   0.626582  0.529412  0.573913
#
#         MCC
# 0  0.453141
# 1  0.299968
# 2  0.404307
# 3  0.424452
# 4  0.398288
# 5  0.439765
